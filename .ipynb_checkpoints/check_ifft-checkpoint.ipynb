# %%
# Import libraries
import numpy as np
import numpy.fft as fft
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image

# %%
rgb_df = pd.read_csv("target.csv", header=None)

# %%
rgb_arr = rgb_df.values
fig = plt.figure()
fig.set_size_inches(8, 8)
ax = fig.add_subplot(111)

ax.imshow(rgb_arr, cmap="gray")

plt.show()

# %%
rgb = rgb_arr[100:480, 170:550]
rgb = rgb / np.sqrt(np.sum(rgb ** 2))
rgb = rgb ** 4

# %%
fig = plt.figure()
fig.set_size_inches(8, 8)
ax = fig.add_subplot(111)

ax.imshow(rgb, cmap="gray")

plt.show()

# %% [markdown]
# large = np.zeros((380 * 11, 380 * 11))
# large[380 * 5:380 * 6, 380 * 5:380 * 6] = rgb
# rgb = large

# %% [markdown]
# fig = plt.figure()
# fig.set_size_inches(8, 8)
# ax = fig.add_subplot(111)
#
# ax.imshow(rgb, cmap="gray")
#
# plt.show()

# %% [markdown]
# canvas = np.zeros(rgb.shape)
# for i in np.arange(rgb.shape[0]):
#     for j in np.arange(rgb.shape[1]):
#         canvas[i][j] = rgb[(i + rgb.shape[0] // 2) % rgb.shape[0]][(j + rgb.shape[1] // 2) % rgb.shape[1]]
# canvas

# %% [markdown]
# fig = plt.figure()
# fig.set_size_inches(8, 8)
# ax = fig.add_subplot(111)
#
# ax.imshow(canvas, cmap="gray")
#
# plt.show()

# %% [markdown]
# np.absolute(fft.ifft(canvas))

# %%
aperture = np.absolute(fft.ifft(rgb))
aperture = aperture / np.sqrt(np.sum(aperture ** 2))

apcanvas = np.zeros(aperture.shape)
for i in np.arange(aperture.shape[0]):
    for j in np.arange(aperture.shape[1]):
        apcanvas[i][j] = aperture[(i + aperture.shape[0] // 2) % aperture.shape[0]][(j + aperture.shape[1] // 2) % aperture.shape[1]]

# %%
apcanvas = apcanvas ** 2

# %%
fig = plt.figure()
fig.set_size_inches(8, 8)
ax = fig.add_subplot(111)

ax.imshow(apcanvas, cmap="gray", interpolation="bilinear", aspect='auto', vmax=0.00000001)

plt.show()
